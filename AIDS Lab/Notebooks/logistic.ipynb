# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
df = pd.read_csv(r'C:\Users\Preeti Khamkar\OneDrive\Desktop\AIDS Lab\weatherHistory.csv')
df = df.drop(range(86200), axis=0)
df = df.reset_index()
df.dropna()
df.shape
# Out:
# (10253, 13)

# %%
df.dropna()
# Out:
#        index                 Formatted_Date        Summary Precip_Type  \
# 0      86200  2015-11-09 20:00:00.000 +0100  Mostly Cloudy        rain
# 1      86201  2015-11-09 21:00:00.000 +0100  Mostly Cloudy        rain
# 2      86202  2015-11-09 22:00:00.000 +0100  Mostly Cloudy        rain
# 3      86203  2015-11-09 23:00:00.000 +0100  Mostly Cloudy        rain
# 4      86204  2015-10-01 00:00:00.000 +0200  Mostly Cloudy        rain
# ...      ...                            ...            ...         ...
# 10248  96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 10249  96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 10250  96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 10251  96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 10252  96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent_Temperature_C  Humidity  Wind Speed (km/h)  \
# 0            14.811111               14.811111      0.79            20.7851
# 1            15.188889               15.188889      0.73            20.7690
# 2            14.494444               14.494444      0.78            15.6009
# 3            13.750000               13.750000      0.81            11.5115
# 4             8.894444                6.327778      0.74            16.9533
# ...                ...                     ...       ...                ...
# 10248        26.016667               26.016667      0.43            10.9963
# 10249        24.583333               24.583333      0.48            10.0947
# 10250        22.038889               22.038889      0.56             8.9838
# 10251        21.522222               21.522222      0.60            10.5294
# 10252        20.438889               20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                         300           8.1305           0
# 1                         310          11.9784           0
# 2                         307          11.6886           0
# 3                         299          12.2199           0
# 4                          21          16.1000           0
# ...                       ...              ...         ...
# 10248                      31          16.1000           0
# 10249                      20          15.5526           0
# 10250                      30          16.1000           0
# 10251                      20          16.1000           0
# 10252                      39          15.5204           0
#
#        Pressure (millibars)                           Daily Summary
# 0                   1022.57                    Foggy until morning.
# 1                   1023.05                    Foggy until morning.
# 2                   1023.30                    Foggy until morning.
# 3                   1023.13                    Foggy until morning.
# 4                   1030.56       Partly cloudy throughout the day.
# ...                     ...                                     ...
# 10248               1014.36  Partly cloudy starting in the morning.
# 10249               1015.16  Partly cloudy starting in the morning.
# 10250               1015.66  Partly cloudy starting in the morning.
# 10251               1015.95  Partly cloudy starting in the morning.
# 10252               1016.16  Partly cloudy starting in the morning.
#
# [9879 rows x 13 columns]

# %%
df.isna
# Out:
# <bound method DataFrame.isna of        index                 Formatted_Date        Summary Precip_Type  \
# 0      86200  2015-11-09 20:00:00.000 +0100  Mostly Cloudy        rain
# 1      86201  2015-11-09 21:00:00.000 +0100  Mostly Cloudy        rain
# 2      86202  2015-11-09 22:00:00.000 +0100  Mostly Cloudy        rain
# 3      86203  2015-11-09 23:00:00.000 +0100  Mostly Cloudy        rain
# 4      86204  2015-10-01 00:00:00.000 +0200  Mostly Cloudy        rain
# ...      ...                            ...            ...         ...
# 10248  96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 10249  96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 10250  96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 10251  96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 10252  96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent_Temperature_C  Humidity  Wind Speed (km/h)  \
# 0            14.811111               14.811111      0.79            20.7851
# 1            15.188889               15.188889      0.73            20.7690
# 2            14.494444               14.494444      0.78            15.6009
# 3            13.750000               13.750000      0.81            11.5115
# 4             8.894444                6.327778      0.74            16.9533
# ...                ...                     ...       ...                ...
# 10248        26.016667               26.016667      0.43            10.9963
# 10249        24.583333               24.583333      0.48            10.0947
# 10250        22.038889               22.038889      0.56             8.9838
# 10251        21.522222               21.522222      0.60            10.5294
# 10252        20.438889               20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                         300           8.1305           0
# 1                         310          11.9784           0
# 2                         307          11.6886           0
# 3                         299          12.2199           0
# 4                          21          16.1000           0
# ...                       ...              ...         ...
# 10248                      31          16.1000           0
# 10249                      20          15.5526           0
# 10250                      30          16.1000           0
# 10251                      20          16.1000           0
# 10252                      39          15.5204           0
#
#        Pressure (millibars)                           Daily Summary
# 0                   1022.57                    Foggy until morning.
# 1                   1023.05                    Foggy until morning.
# 2                   1023.30                    Foggy until morning.
# 3                   1023.13                    Foggy until morning.
# 4                   1030.56       Partly cloudy throughout the day.
# ...                     ...                                     ...
# 10248               1014.36  Partly cloudy starting in the morning.
# 10249               1015.16  Partly cloudy starting in the morning.
# 10250               1015.66  Partly cloudy starting in the morning.
# 10251               1015.95  Partly cloudy starting in the morning.
# 10252               1016.16  Partly cloudy starting in the morning.
#
# [10253 rows x 13 columns]>

# %%
df.columns
# Out:
# Index(['index', 'Formatted_Date', 'Summary', 'Precip_Type', 'Temperature (C)',
#        'Apparent_Temperature_C', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
data = df[['Precip_Type', 'Humidity', 'Temperature (C)']]

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()

# %%
data = data.replace('rain',0)
data = data.replace('snow', 1)

# %%
from sklearn.model_selection import GridSearchCV
parameter ={'penalty' : ['l2'] , 'C': [1,2,3,4,5,6,10,20,30,40,50] , 'max_iter': [100,200,300,]}

# %%
# from sklearn.model_selection import train_test_split
x = data[['Temperature (C)', 'Humidity']]
y = data['Precip_Type']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
reg_model = GridSearchCV(reg , param_grid = parameter , scoring = 'accuracy' , cv= 5 , error_score='raise')
reg_model.fit(x_train , y_train)
# Out:
# c:\Users\Preeti Khamkar\Python__\Lib\site-packages\sklearn\utils\_array_api.py:290: RuntimeWarning: invalid value encountered in cast
#   return x.astype(dtype, copy=copy, casting=casting)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 reg_model = GridSearchCV(reg , param_grid = parameter , scoring = 'accuracy' , cv= 5 , error_score='raise')
# ----> 2 reg_model.fit(x_train , y_train)
#
# File c:\Users\Preeti Khamkar\Python__\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Preeti Khamkar\Python__\Lib\site-packages\sklearn\model_selection\_search.py:879, in BaseSearchCV.fit(self, X, y, **params)
#     875 params = _check_method_params(X, params=params)
#     877 routed_params = self._get_routed_params_for_fit(params)
# --> 879 cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
#     880 n_splits = cv_orig.get_n_splits(X, y, **routed_params.splitter.split)
#     882 base_estimator = clone(self.estimator)
#
# File c:\Users\Preeti Khamkar\Python__\Lib\site-packages\sklearn\model_selection\_split.py:2525, in check_cv(cv, y, classifier)
#    2520 cv = 5 if cv is None else cv
#    2521 if isinstance(cv, numbers.Integral):
#    2522     if (
#    2523         classifier
#    2524         and (y is not None)
# -> 2525         and (type_of_target(y, input_name="y") in ("binary", "multiclass"))
#    2526     ):
#    2527         return StratifiedKFold(cv)
#    2528     else:
#
# File c:\Users\Preeti Khamkar\Python__\Lib\site-packages\sklearn\utils\multiclass.py:389, in type_of_target(y, input_name)
#     387     data = y.data if issparse(y) else y
#     388     if xp.any(data != xp.astype(data, int)):
# --> 389         _assert_all_finite(data, input_name=input_name)
#     390         return "continuous" + suffix
#     392 # Check multiclass
#
# File c:\Users\Preeti Khamkar\Python__\Lib\site-packages\sklearn\utils\validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File c:\Users\Preeti Khamkar\Python__\Lib\site-packages\sklearn\utils\validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input y contains NaN.
